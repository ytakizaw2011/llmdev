# %% [markdown]
# Lesson 12 Chapter 3.1 Excelデータ全体をまとめて処理する方法

# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from openai import OpenAI
import pandas as pd

# 環境変数の取得
load_dotenv()

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# %%
# 1. Excelファイルを読み込む
df = pd.read_excel('サンプルデータ.xlsx', sheet_name='売上データ')
# データフレームを表示して確認
df.head()
# Out:
#   カテゴリー  商品コード   商品名        売上日    単価   数量    原価
# 0    食品   1001   りんご 2023-01-01   200   50   120
# 1    食品   1002   バナナ 2023-01-01   150  100    80
# 2    食品   1003    牛乳 2023-01-02   180   80   100
# 3    衣服   2001  Tシャツ 2023-01-02  1500   20   800
# 4    衣服   2002  ジーンズ 2023-01-03  5000   10  2500

# %%
# 2. データをLLM用にテキスト形式に変換
# データフレーム全体を文字列に変換
sales_data_text = df.astype(str)
prompt_text = f"売上データ:\n{sales_data_text}\nこの売上データの傾向を分析してください。"
# 表示して確認
print(prompt_text)
# Out:
# 売上データ:
#     カテゴリー 商品コード      商品名         売上日    単価   数量    原価
# 0      食品  1001      りんご  2023-01-01   200   50   120
# 1      食品  1002      バナナ  2023-01-01   150  100    80
# 2      食品  1003       牛乳  2023-01-02   180   80   100
# 3      衣服  2001     Tシャツ  2023-01-02  1500   20   800
# 4      衣服  2002     ジーンズ  2023-01-03  5000   10  2500
# ..    ...   ...      ...         ...   ...  ...   ...
# 235    衣服  2077   レインパンツ  2023-04-28  2000   18  1000
# 236    食品  1085      ザクロ  2023-04-29   600   40   300
# 237   日用品  3077    バスブラシ  2023-04-29   400   60   200
# 238    衣服  2078  レインシューズ  2023-04-30  2500   15  1250
# 239    食品  1086    ココナッツ  2023-04-30   300   80   150
#
# [240 rows x 7 columns]
# この売上データの傾向を分析してください。

# %%
# 3. OpenAI APIの呼び出し

# 役割を設定
role = "あなたはマーケティング分野に精通したデータサイエンティストです。企業の成長をサポートするために、効果的なインサイトを提供します。"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": role},
        {"role": "user", "content": prompt_text},
    ],
)

# LLMからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# この売上データからいくつかの傾向を分析するために、以下のポイントに注目します。
#
# ### 1. 売上のカテゴリ別分析
# - **食品、衣服、日用品:** 売上データには、食品、衣服、日用品の3つのカテゴリーが含まれています。
# - データを集計して、各カテゴリーの売上合計および取引数を算出します。たとえば、食品の売上が一番多いのか、衣服が強いのかを見ます。
#
# ### 2. 商品ごとのパフォーマンス
# - 各商品の売上と数量を解析し、どの商品が売れ筋であるかを特定します。
# - 単価に対する原価を考慮し、利益率を計算することで、最も利益を上げている商品を特定します。
#
# ### 3. 日付別の売上傾向
# - 売上日を基に時系列データを生成し、月ごとの売上推移を可視化します。
# - 季節性や特定のイベント（例:連休や特定の季節）との関連を探ります。
#
# ### 4. 売上数量と単価の相関
# - 各商品の販売数量と単価の関係を分析し、価格戦略に対する洞察を得ます。単価が高い商品ほど売れるのか、逆に安い商品が良く売れるのかを分析します。
#
# ### 5. 利益率の分析
# - 商品ごとの利益を計算し、原価を考慮した上で収益性の高い商品やカテゴリを特定します。
#
# ### 6. トレンドの発掘
# - 売上データの移動平均や指数平滑化を用いてトレンドを視覚化し、将来の売上予測に役立てます。
#
# ### 例: 基本的な集計と結果
# 以下のように簡易的な分析結果を考慮します。
#
# ```python
# import pandas as pd
#
# data = {
#     'カテゴリー': [...],  # カテゴリーデータ
#     '商品コード': [...],  # 商品コード
#     '商品名': [...],  # 商品名
#     '売上日': [...],  # 売上日
#     '単価': [...],  # 単価
#     '数量': [...],  # 数量
#     '原価': [...]  # 原価
# }
#
# df = pd.DataFrame(data)
#
# # カテゴリー別売上集計
# category_sales = df.groupby('カテゴリー').agg({'単価': 'sum', '数量': 'sum', '原価': 'sum'}).reset_index()
#
# # 商品別分析
# product_performance = df.groupby('商品名').agg({'単価': 'sum', '数量': 'sum'}).reset_index()
#
# # 日付別売上集計
# daily_sales = df.groupby('売上日').agg({'単価': 'sum'}).reset_index()
#
# # 利益の計算
# df['利益'] = df['単価'] - df['原価']
# profit_analysis = df.groupby('商品名').agg({'利益': 'sum'}).reset_index()
#
# ```
#
# このように、各種データを集計・分析することで、売上データの全体像を把握し、戦略的な意思決定をサポートするインサイトを提供します。この分析から得たインサイトをもとに、マーケティング戦略や販促活動を最適化することができます。

# %%
# 4. 分析結果をデータフレームに変換
result_list = response.choices[0].message.content.strip().split("\n")
df_out = pd.DataFrame(result_list, columns=['結果'])
print(df_out)
# Out:
#                                                    結果
# 0             この売上データからいくつかの傾向を分析するために、以下のポイントに注目します。
# 1
# 2                                   ### 1. 売上のカテゴリ別分析
# 3   - **食品、衣服、日用品:** 売上データには、食品、衣服、日用品の3つのカテゴリーが含ま...
# 4   - データを集計して、各カテゴリーの売上合計および取引数を算出します。たとえば、食品の売上が...
# 5
# 6                                 ### 2. 商品ごとのパフォーマンス
# 7                 - 各商品の売上と数量を解析し、どの商品が売れ筋であるかを特定します。
# 8      - 単価に対する原価を考慮し、利益率を計算することで、最も利益を上げている商品を特定します。
# 9
# 10                                    ### 3. 日付別の売上傾向
# 11                - 売上日を基に時系列データを生成し、月ごとの売上推移を可視化します。
# 12                - 季節性や特定のイベント（例:連休や特定の季節）との関連を探ります。
# 13
# 14                                  ### 4. 売上数量と単価の相関
# 15  - 各商品の販売数量と単価の関係を分析し、価格戦略に対する洞察を得ます。単価が高い商品ほど売...
# 16
# 17                                      ### 5. 利益率の分析
# 18        - 商品ごとの利益を計算し、原価を考慮した上で収益性の高い商品やカテゴリを特定します。
# 19
# 20                                     ### 6. トレンドの発掘
# 21     - 売上データの移動平均や指数平滑化を用いてトレンドを視覚化し、将来の売上予測に役立てます。
# 22
# 23                                   ### 例: 基本的な集計と結果
# 24                              以下のように簡易的な分析結果を考慮します。
# 25
# 26                                          ```python
# 27                                import pandas as pd
# 28
# 29                                           data = {
# 30                        'カテゴリー': [...],  # カテゴリーデータ
# 31                           '商品コード': [...],  # 商品コード
# 32                               '商品名': [...],  # 商品名
# 33                               '売上日': [...],  # 売上日
# 34                                 '単価': [...],  # 単価
# 35                                 '数量': [...],  # 数量
# 36                                  '原価': [...]  # 原価
# 37                                                  }
# 38
# 39                            df = pd.DataFrame(data)
# 40
# 41                                       # カテゴリー別売上集計
# 42  category_sales = df.groupby('カテゴリー').agg({'単価'...
# 43
# 44                                            # 商品別分析
# 45  product_performance = df.groupby('商品名').agg({'...
# 46
# 47                                          # 日付別売上集計
# 48  daily_sales = df.groupby('売上日').agg({'単価': 'su...
# 49
# 50                                            # 利益の計算
# 51                     df['利益'] = df['単価'] - df['原価']
# 52  profit_analysis = df.groupby('商品名').agg({'利益':...
# 53
# 54                                                ```
# 55
# 56  このように、各種データを集計・分析することで、売上データの全体像を把握し、戦略的な意思決定を...

# %%
# 5. 結果をExcelファイルに保存
df_out.to_excel("売上データ分析結果.xlsx", index=False)

# %%
# ワークフロー化
print("処理を開始します。")

# 1. Excelファイルを読み込む
df = pd.read_excel('サンプルデータ.xlsx', sheet_name='売上データ')

# 2. データをLLM用にテキスト形式に変換
sales_data_text = df.astype(str)
prompt_text = f"売上データ:\n{sales_data_text}\nこの売上データの傾向を分析してください。"

# 3. OpenAI APIの呼び出し
# 役割を設定
role = "あなたはマーケティング分野に精通したデータサイエンティストです。企業の成長をサポートするために、効果的なインサイトを提供します。"
# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": role},
        {"role": "user", "content": prompt_text},
    ],
)

# 4. 分析結果をデータフレームに変換
result_list = response.choices[0].message.content.strip().split("\n")
df_out = pd.DataFrame(result_list, columns=['結果'])

# 5. 結果をExcelファイルに保存
df_out.to_excel("売上データ分析結果.xlsx", index=False)

print("Excelファイルに分析結果を保存しました。")
# Out:
# 処理を開始します。
# Excelファイルに分析結果を保存しました。
